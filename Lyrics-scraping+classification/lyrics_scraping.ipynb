# %%
import urllib2
from bs4 import BeautifulSoup

britney_spears_songs_html = urllib2.urlopen('https://www.lyrics.com/artist/Britney+Spears/320976')

my_html = britney_spears_songs_html.read()

my_html_soup = BeautifulSoup(my_html, 'html.parser')

my_html_soup = my_html_soup.prettify()

# %%
print my_html_soup
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <!-- DFP head code - START -->
#   <script>
#    var adsStart = (new Date()).getTime();
#     function detectWidth() {
#         return window.screen.width || window.innerWidth || window.document.documentElement.clientWidth || Math.min(window.innerWidth, window.document.documentElement.clientWidth) || window.innerWidth || window.document.documentElement.clientWidth || window.document.getElementsByTagName('body')[0].clientWidth;
#     }
#
#     var TIMEOUT = 1000;
#     var EXCHANGE_RATE = 3.6;
#     var screenSizeMobile = 768;
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     var pbjs = pbjs || {};
# ...

# %%
import re

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

str(song_urls[0])
len(song_urls)
# Out:
# 258

# %%
url_general = "https://www.lyrics.com"
url = url_general + song_urls[57]
print url
# Out:
# https://www.lyrics.com/lyric/5182476/Britney+Spears/That%27s+Where+You+Take+Me

# %%
song_1 = urllib2.urlopen(url)
song_1_html = song_1.read()

song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')

#song_1_html_soup = song_1_html_soup.prettify()

lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
#print lyrics

# %%
import sys
import urllib2
import re
from bs4 import BeautifulSoup
reload(sys)
sys.setdefaultencoding('utf8')

url_general = "https://www.lyrics.com"

songs_html = urllib2.urlopen('https://www.lyrics.com/artist/Britney+Spears/320976')

my_html = songs_html.read()
my_html_soup = BeautifulSoup(my_html, 'html.parser').prettify()

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

url = [url_general + a for a in song_urls]
index = 0

for url in url:
    index = index + 1
    song_1 = urllib2.urlopen(url)
    song_1_html = song_1.read()
    song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')
    #song_1_html_soup = song_1_html_soup.prettify()
    lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
    #with open('song_{}.txt'.format(index), 'w') as output:
    #      output.write(lyrics)
    with open('song_all_britneyspears.txt'.format(index), 'a') as output_new:
             output_new.write(lyrics)
             output_new.write('\n')
             output_new.write('\n')

# %%
import sys
import urllib2
import re
from bs4 import BeautifulSoup
reload(sys)
sys.setdefaultencoding('utf8')

url_general = "https://www.lyrics.com"

songs_html = urllib2.urlopen('https://www.lyrics.com/artist/Michael+Jackson/4576')

my_html = songs_html.read()
my_html_soup = BeautifulSoup(my_html, 'html.parser').prettify()

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

url = [url_general + a for a in song_urls]
index = 0

for url in url:
    index = index + 1
    song_1 = urllib2.urlopen(url)
    song_1_html = song_1.read()
    song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')
    #song_1_html_soup = song_1_html_soup.prettify()
    lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
    #with open('song_{}.txt'.format(index), 'w') as output:
    #      output.write(lyrics)
    with open('song_all_MJ.txt'.format(index), 'a') as output_new:
             output_new.write(lyrics)
             output_new.write('\n')
             output_new.write('\n')

# %%
import sys
import urllib2
import re
from bs4 import BeautifulSoup
reload(sys)
sys.setdefaultencoding('utf8')

url_general = "https://www.lyrics.com"

songs_html = urllib2.urlopen('https://www.lyrics.com/artist/Madonna/64565')

my_html = songs_html.read()
my_html_soup = BeautifulSoup(my_html, 'html.parser').prettify()

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

url = [url_general + a for a in song_urls]
index = 0

for url in url:
    index = index + 1
    song_1 = urllib2.urlopen(url)
    song_1_html = song_1.read()
    song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')
    #song_1_html_soup = song_1_html_soup.prettify()
    lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
    #with open('song_{}.txt'.format(index), 'w') as output:
    #      output.write(lyrics)
    with open('song_all_Madonna.txt'.format(index), 'a') as output_new:
             output_new.write(lyrics)
             output_new.write('\n')
             output_new.write('\n')

# %%
import sys
import urllib2
import re
from bs4 import BeautifulSoup
reload(sys)
sys.setdefaultencoding('utf8')

url_general = "https://www.lyrics.com"

songs_html = urllib2.urlopen('https://www.lyrics.com/artist/Elvis+Presley/5175')

my_html = songs_html.read()
my_html_soup = BeautifulSoup(my_html, 'html.parser').prettify()

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

url = [url_general + a for a in song_urls]
index = 0

for url in url:
    index = index + 1
    song_1 = urllib2.urlopen(url)
    song_1_html = song_1.read()
    song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')
    #song_1_html_soup = song_1_html_soup.prettify()
    lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
    #with open('song_{}.txt'.format(index), 'w') as output:
    #      output.write(lyrics)
    with open('song_all_Elvis_Presley.txt'.format(index), 'a') as output_new:
             output_new.write(lyrics)
             output_new.write('\n')
             output_new.write('\n')

# %%
import sys
import urllib2
import re
from bs4 import BeautifulSoup
reload(sys)
sys.setdefaultencoding('utf8')

url_general = "https://www.lyrics.com"

songs_html = urllib2.urlopen('https://www.lyrics.com/artist/The+Beatles/3644')

my_html = songs_html.read()
my_html_soup = BeautifulSoup(my_html, 'html.parser').prettify()

song_urls = re.findall("\"(/lyric/[^\"]+)\">", my_html_soup)

url = [url_general + a for a in song_urls]
index = 0

for url in url:
    index = index + 1
    song_1 = urllib2.urlopen(url)
    song_1_html = song_1.read()
    song_1_html_soup = BeautifulSoup(song_1_html, 'html.parser')
    #song_1_html_soup = song_1_html_soup.prettify()
    lyrics = song_1_html_soup.find("pre", class_="lyric-body").get_text()
    #with open('song_{}.txt'.format(index), 'w') as output:
    #      output.write(lyrics)
    with open('song_all_Beatles.txt'.format(index), 'a') as output_new:
             output_new.write(lyrics)
             output_new.write('\n')
             output_new.write('\n')
